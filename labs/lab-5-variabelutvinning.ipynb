# %% [markdown]
# # Variabelutvinning
#
# Her ser vi på data fra filmrangeringer. Målet er å predikere hva slage rangering forskiellige brukere gir til filemer basert på data om filmene og brukere.
#
# Her har jeg lagd en enkel modell for det. Dere har tre oppgaver:
#
# 1. Les gjennom koden og prøv å forstå den.
# 2. I grupper, lag en liste av minst 10 forskjellige mulige variabler (basert på de eksisterende data) som kunne hjelpe å forbedre prediksjonene.
# 3. Implementer de tre variablene som du tror mest på at hjelper.
# 4. Basert på resultatene, velg ut hvilke variabler du faktisk vil ha med.

# %%
# importer nødvendige pakker
import numpy as np
import pandas as pd
from datetime import datetime
#import pgeocode 

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error

# %%
# lese inn data 
df_ranking = pd.read_csv('./data/ratings.dat', sep='::', engine='python', header=None, 
                         names = ['UserID', 'FilmID', 'Ranking', 'Timestamp'])
df_ranking['Timestamp'] = pd.to_datetime(df_ranking['Timestamp'], unit='s')
df_user = pd.read_csv('./data/users.dat', sep='::', header=None, 
                      names=['UserID', 'Sex', 'Age', 'Job', 'Post code'], 
                      engine='python')
df_film = pd.read_csv('./data/movies.dat', sep='::', header=None,
                      names=['FilmID', 'Title', 'Genre'], 
                      encoding='latin-1', engine='python')

# %%
# se på ranking-data
df_ranking.head()
# Out:
#    UserID  FilmID  Ranking           Timestamp
# 0       1    1193        5 2000-12-31 22:12:40
# 1       1     661        3 2000-12-31 22:35:09
# 2       1     914        3 2000-12-31 22:32:48
# 3       1    3408        4 2000-12-31 22:04:35
# 4       1    2355        5 2001-01-06 23:38:11

# %%
# se på bruker-data
df_user.head()
# Out:
#    UserID Sex  Age  Job Post code
# 0       1   F    1   10     48067
# 1       2   M   56   16     70072
# 2       3   M   25   15     55117
# 3       4   M   45    7     02460
# 4       5   M   25   20     55455

# %%
# se på film-data
df_film.head()
# Out:
#    FilmID                               Title                         Genre
# 0       1                    Toy Story (1995)   Animation|Children's|Comedy
# 1       2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2       3             Grumpier Old Men (1995)                Comedy|Romance
# 3       4            Waiting to Exhale (1995)                  Comedy|Drama
# 4       5  Father of the Bride Part II (1995)                        Comedy

# %%
# kombiner data
df_combined = df_ranking.merge(df_user, how='left', on='UserID').merge(df_film, how='left', on='FilmID')
df_combined.sort_values(by='UserID', ascending=False).head(50)
# Out:
#          UserID  FilmID  Ranking           Timestamp Sex  Age  Job Post code  \
# 1000208    6040    1097        4 2000-04-26 02:19:29   M   25    6     11106
# 999984     6040    2575        4 2001-08-10 14:29:22   M   25    6     11106
# 999976     6040    1587        1 2000-04-26 02:32:54   M   25    6     11106
# 999977     6040    1594        3 2000-07-28 23:56:39   M   25    6     11106
# 999978     6040    3504        4 2000-06-14 08:37:37   M   25    6     11106
# 999979     6040    1900        5 2000-07-28 23:52:32   M   25    6     11106
# 999980     6040    3505        4 2000-04-25 23:07:36   M   25    6     11106
# 999981     6040    1912        3 2000-07-28 23:55:42   M   25    6     11106
# 999982     6040    2571        4 2001-08-10 14:35:26   M   25    6     11106
# 999983     6040     300        2 2000-04-25 23:18:36   M   25    6     11106
# 999985     6040     306        4 2000-05-07 16:25:54   M   25    6     11106
# 999995     6040    3547        4 2000-06-14 08:52:21   M   25    6     11106
# 999986     6040    3521        5 2000-04-26 02:19:29   M   25    6     11106
# 999987     6040    3524        1 2000-04-26 02:31:03   M   25    6     11106
# 999988     6040    1921        4 2001-08-10 14:41:04   M   25    6     11106
# 999989     6040    2580        4 2000-04-25 23:24:16   M   25    6     11106
# 999990     6040    1929        5 2000-05-07 16:27:41   M   25    6     11106
# 999991     6040     318        4 2000-04-25 23:10:57   M   25    6     11106
# 999992     6040     326        4 2000-04-25 23:15:19   M   25    6     11106
# 999993     6040    2599        5 2000-05-07 16:29:09   M   25    6     11106
# 999975     6040    3182        5 2001-03-10 03:41:22   M   25    6     11106
# 999974     6040    2513        1 2000-04-26 02:35:41   M   25    6     11106
# 999973     6040    2512        5 2000-04-26 02:16:23   M   25    6     11106
# 999972     6040    3168        4 2000-07-29 00:01:40   M   25    6     11106
# 999955     6040    1188        4 2000-07-28 23:55:03   M   25    6     11106
# 999956     6040    1189        5 2000-04-26 02:14:48   M   25    6     11106
# 999957     6040    2134        1 2000-04-26 02:31:34   M   25    6     11106
# 999958     6040    1193        4 2000-05-07 16:23:32   M   25    6     11106
# 999959     6040    1196        3 2000-04-26 02:17:35   M   25    6     11106
# 999960     6040    1198        3 2000-04-26 02:17:35   M   25    6     11106
# 999961     6040    1199        5 2000-04-26 02:17:35   M   25    6     11106
# 999962     6040    2146        1 2000-04-26 02:32:54   M   25    6     11106
# 999963     6040    2147        2 2000-04-26 02:36:28   M   25    6     11106
# 999964     6040    2150        3 2000-04-26 02:23:54   M   25    6     11106
# 999965     6040    3101        4 2000-04-26 02:24:25   M   25    6     11106
# 999966     6040    3108        4 2000-06-14 08:39:52   M   25    6     11106
# 999967     6040    3111        5 2000-04-25 23:07:36   M   25    6     11106
# 999968     6040    3134        5 2000-05-07 16:32:03   M   25    6     11106
# 999969     6040    1537        5 2000-04-25 23:19:48   M   25    6     11106
# 999970     6040    1554        2 2000-04-25 23:19:48   M   25    6     11106
# 999971     6040    2503        5 2000-04-25 23:09:51   M   25    6     11106
# 999994     6040    3543        4 2000-04-26 02:16:23   M   25    6     11106
# 999996     6040    1945        5 2000-05-07 16:34:34   M   25    6     11106
# 999953     6040     649        5 2000-04-25 23:10:57   M   25    6     11106
# 1000027    6040    2938        4 2000-05-07 16:28:24   M   25    6     11106
# 1000019    6040    2917        4 2001-08-10 14:40:29   M   25    6     11106
# 1000020    6040    2919        5 2000-06-14 08:52:40   M   25    6     11106
# 1000021    6040    1974        1 2000-04-26 02:34:38   M   25    6     11106
# 1000022    6040    1975        1 2000-04-26 02:19:29   M   25    6     11106
# 1000023    6040      45        3 2000-04-25 23:22:33   M   25    6     11106
#
#                                                      Title  \
# 1000208                  E.T. the Extra-Terrestrial (1982)
# 999984   Dreamlife of Angels, The (La Vie rêvée des ang...
# 999976                          Conan the Barbarian (1982)
# 999977                        In the Company of Men (1997)
# 999978                                      Network (1976)
# 999979   Children of Heaven, The (Bacheha-Ye Aseman) (1...
# 999980                                   No Way Out (1987)
# 999981                                 Out of Sight (1998)
# 999982                                  Matrix, The (1999)
# 999983                                    Quiz Show (1994)
# 999985                            Three Colors: Red (1994)
# 999995                           Prick Up Your Ears (1987)
# 999986                                Mystery Train (1989)
# 999987                                       Arthur (1981)
# 999988                                           Pi (1998)
# 999989                                           Go (1999)
# 999990                                  Grand Hotel (1932)
# 999991                    Shawshank Redemption, The (1994)
# 999992                             To Live (Huozhe) (1994)
# 999993                                     Election (1999)
# 999975   Mr. Death: The Rise and Fall of Fred A. Leucht...
# 999974                                 Pet Sematary (1989)
# 999973   Ballad of Narayama, The (Narayama Bushiko) (1982)
# 999972                                   Easy Rider (1969)
# 999955                            Strictly Ballroom (1992)
# 999956                          Thin Blue Line, The (1988)
# 999957                                Weird Science (1985)
# 999958              One Flew Over the Cuckoo's Nest (1975)
# 999959   Star Wars: Episode V - The Empire Strikes Back...
# 999960                      Raiders of the Lost Ark (1981)
# 999961                                       Brazil (1985)
# 999962                              St. Elmo's Fire (1985)
# 999963                   Clan of the Cave Bear, The (1986)
# 999964                      Gods Must Be Crazy, The (1980)
# 999965                             Fatal Attraction (1987)
# 999966                             Fisher King, The (1991)
# 999967                          Places in the Heart (1984)
# 999968         Grand Illusion (Grande illusion, La) (1937)
# 999969            Shall We Dance? (Shall We Dansu?) (1996)
# 999970                             Pillow Book, The (1995)
# 999971                             Apple, The (Sib) (1998)
# 999994                                        Diner (1982)
# 999996                            On the Waterfront (1954)
# 999953                  Cold Fever (Á köldum klaka) (1994)
# 1000027  Man Facing Southeast (Hombre Mirando al Sudest...
# 1000019                                   Body Heat (1981)
# 1000020                  Year of Living Dangerously (1982)
# 1000021                             Friday the 13th (1980)
# 1000022                      Friday the 13th Part 2 (1981)
# 1000023                                  To Die For (1995)
#
#                                      Genre
# 1000208    Children's|Drama|Fantasy|Sci-Fi
# 999984                               Drama
# 999976                    Action|Adventure
# 999977                               Drama
# 999978                        Comedy|Drama
# 999979                               Drama
# 999980                            Thriller
# 999981                Action|Crime|Romance
# 999982              Action|Sci-Fi|Thriller
# 999983                               Drama
# 999985                               Drama
# 999995                               Drama
# 999986                  Comedy|Crime|Drama
# 999987                      Comedy|Romance
# 999988                     Sci-Fi|Thriller
# 999989                               Crime
# 999990                               Drama
# 999991                               Drama
# 999992                               Drama
# 999993                              Comedy
# 999975                         Documentary
# 999974                              Horror
# 999973                               Drama
# 999972                     Adventure|Drama
# 999955                      Comedy|Romance
# 999956                         Documentary
# 999957                              Comedy
# 999958                               Drama
# 999959   Action|Adventure|Drama|Sci-Fi|War
# 999960                    Action|Adventure
# 999961                              Sci-Fi
# 999962                       Drama|Romance
# 999963                               Drama
# 999964                              Comedy
# 999965                            Thriller
# 999966                Comedy|Drama|Romance
# 999967                               Drama
# 999968                           Drama|War
# 999969                              Comedy
# 999970                       Drama|Romance
# 999971                               Drama
# 999994                        Comedy|Drama
# 999996                         Crime|Drama
# 999953                        Comedy|Drama
# 1000027                              Drama
# 1000019                     Crime|Thriller
# 1000020                      Drama|Romance
# 1000021                             Horror
# 1000022                             Horror
# 1000023                       Comedy|Drama

# %%
# del data i trenings-, validerings-, og testdata
df_train, df_valtest = train_test_split(df_combined, test_size=0.3, random_state=0)
df_val, df_test = train_test_split(df_valtest, test_size=0.5, random_state=0)

# %%
# forberede y 
def prepare_y(df):
    return df.Ranking.values
def prepare_ys(dfs):
    return (prepare_y(df) for df in dfs)

# %% [markdown]
# Det er `prepare_X`-funksjonen som bør oppdateres, slik at X inneholder flere relevante kolonner som kan brukes til å predikere rangeringer.

# %%
# forberede X 
def prepare_X(df):
    numeric_cols = ["Ranking","FilmID","Job"]
    return df.loc[:, numeric_cols]

def prepare_Xs(dfs):
    return (prepare_X(df) for df in dfs)

# %%
# faktiske dataforberedelse
X_train, X_val, X_test = prepare_Xs((df_train, df_val, df_test))
y_train, y_val, y_test = prepare_ys((df_train, df_val, df_test))

# %%
# se på X fra tranings-data 
X_train.head()
# Out:
#         Ranking  FilmID  Job
# 103224        2    1220    4
# 495518        5    1409   16
# 762996        4     344   19
# 611883        4    2336   12
# 531137        1    1726    7

# %%
# regresjon 
reg = LinearRegression()
scaler = StandardScaler()
imp = SimpleImputer(strategy='mean')
model = make_pipeline(imp, scaler, reg)

model.fit(X_train, y_train)
pred = model.predict(X_val).clip(min=1, max=5)
rmse = mean_squared_error(y_val, pred, squared=False)
print(rmse)
# Out:
# 5.915086596300538e-16

# %% [markdown]
# Mulig variabler:
#
# 1. Ranking
#
# For å gjette ranking, så burde man ha med ranking
#
# 2. FilmID
#
# En film er ikke bra eller dårlig, men gjennomsnittet av det alle stemmer viser hvor god filmen er.
#
# 3. Age
#
# Age kan ha noe å si, men da må man ha med ```FilmID``` siden noen filmer med noen id-er vil få en bedre score sammen med alder
#
# 4. Jobb
#
# Jobb vil kunne ha noe å si.
#
# 5. Sex
#
# Kan være at menn/kvinner gir forskjellig score (litt mindre/mer) score basert på kjønn.
#
# 6. UserID
#
# Noen brukere kan generelt gi dårlig scores, eller bedre. Dette kan hjelp en del
#
# 7. Timestamp
#
# Transform to just year
#
#
#
#
# ### Tror ikke blir bra:
# PostCode - ikke verdi + ikke numeric
# Timestamp - Skal ikke ha noe å si  + ikke numeric
# Title - FilmID er mye bedre + ikke numeric
# Genre - ikke numeric
#
#
# **['Age']**
#
# 1.11
#
# **['Age',"FilmID"]**
#
# 1.11
#
# ### RANKING ER VELDIG VIKTIG!!!
#
# **['Age',"Ranking"]**
#
# 1.09776e-15
#
# **['Age',"Ranking","FilmID"]**
#
# 9.845454659780244e-16
#
# **["Ranking","FilmID","Job"]**
#
# 5.915086596300538e-16  ***minst***
#
# **['Age',"Ranking","FilmID","Job"]**
#
# 1.1843520163624952e-15
#
# **['Age',"Ranking","FilmID","Job","UserID"]**
#
# 1.3927981302580887e-15
#
# **['Age',"Ranking","FilmID","Job","Postcode"]**
#
# dont work
